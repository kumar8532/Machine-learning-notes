# %%
# it is only theoretical topic 
it is all about the feature extractions 
and how many types of features extract 
#1.feature transformation 
#2.feature construction 
#3.feature selection 
#4.feature extraction
