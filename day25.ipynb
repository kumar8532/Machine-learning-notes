# %%
#NORMALIZATION 
it is a technique often applied as part of data preparation for machine learning . the goal of normalization is to 
change the values of numeric columns in the dataset to use a common scale ,without distoring difference
in the ranges of values or losing information 
#MIN MAX SCALING 
#MEAN NORMALIZATION
#MAX ABSOLUTE 
#ROBUSST SCALING

# %%
#MINMAXSCALING - INTUITION

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']
print(df)
print(df.columns)
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]
# Index(['Class label', 'Alcohol', 'Malic acid'], dtype='object')
