# %%
#what is feature scalling?
feature scalling is a technique to standarze the independent features present in the data in a fixed range

# %%
#STANDARDIZATION INTUITION 
Also called as z-score Normalization
it has only two factor 
mean and scaling by the factore of zeometric institution
